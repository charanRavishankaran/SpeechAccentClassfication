# %%
import librosa
audio_path = 'Egor - text.wav'
x , sr = librosa.load(audio_path)
print(type(x), type(sr))
print(x,sr)
librosa.load(audio_path, sr=44100)
# Out:
# <class 'numpy.ndarray'> <class 'int'>
# [ 4.8659911e-07 -6.5269342e-06  1.1070318e-06 ... -7.9786201e-04
#  -9.6389686e-04  0.0000000e+00] 22050
# (array([ 0.        ,  0.        ,  0.        , ..., -0.00085449,
#         -0.00094604, -0.00094604], dtype=float32), 44100)

# %%
#Plotting the whole wave
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)

# %%
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz') 
#If to pring log of frequencies  
#librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()

# %%
x, sr = librosa.load("Egor - text.wav")
#Plot the signal:
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)

# %%
#zooming the wave
n0 = 9000
n1 = 9100
plt.figure(figsize=(14, 5))
plt.plot(x[n0:n1])
plt.grid()

# %%
#displaying 13th order MFCCs
mfccs = librosa.feature.mfcc(x, sr=sr,n_mfcc=13)
print(mfccs.shape)
#Displaying  the MFCCs:
librosa.display.specshow(mfccs, sr=sr, x_axis='time')
# Out:
# (13, 2729)
